# %% [markdown]
# This notebook contains my learning and practice codes of the chapter 2

# %%
# !pip install faker 
# !pip install radar
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.8 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 2.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for radar: filename=radar-0.3-py3-none-any.whl size=4996 sha256=92ca476b0d488a751dd404749ac00d17ae8b7e3c4afb21b59e4d69c174d38b2b
#   Stored in directory: c:\users\pg900\appdata\local\pip\cache\wheels\e8\67\aa\a63ff0c78f8e447ef451a9d033290153358237ce8bcdf6836b
# Successfully built radar
# ...

# %%
#importing libraries
import datetime
import math
import pandas as pd
import random 
import radar 
import matplotlib.pyplot as plt
from faker import Faker
fake = Faker()

# %%
def generateData(n):
  listdata = []
  start = datetime.datetime(2019, 8, 1)
  end = datetime.datetime(2019, 8, 30)
  delta = end - start
  for _ in range(n):
    date = radar.random_datetime(start='2019-08-1', stop='2019-08-30').strftime("%Y-%m-%d")
    price = round(random.uniform(900, 1000), 4)
    listdata.append([date, price])
  df = pd.DataFrame(listdata, columns = ['Date', 'Price'])
  df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')
  df = df.groupby(by='Date').mean()

  return df

# %%
df = generateData(20)

# %%
df.head(10)
# Out:
#                 Price
# Date
# 2019-08-01  962.02265
# 2019-08-02  951.24800
# 2019-08-04  918.14130
# 2019-08-05  950.67480
# 2019-08-08  994.86250
# 2019-08-11  900.60590
# 2019-08-15  934.27880
# 2019-08-16  998.56840
# 2019-08-17  925.64500
# 2019-08-19  973.88295

# %%
#plotting the line chart for the data

plt.rcParams['figure.figsize'] = (20, 5)
plt.plot(df)

# %% [markdown]
# **Bar chart**

# %%
#importing libraries
import numpy as np
import matplotlib.pyplot as plt
import calendar

#generating data
months = list(range(1, 13))
sales_quantity = [random.randint(100, 1000) for _ in months]

plt.rcParams['figure.figsize'] = (12, 5)
fig, axis = plt.subplots()
plt.xticks(months, calendar.month_name[1:13], rotation=20)
axis.bar(months, sales_quantity, width = 0.5)
plt.show()

# %%
#Plotting the horizontal bar chart

plt.rcParams['figure.figsize'] = (12, 6)
fig, ax = plt.subplots()
plt.yticks(months, calendar.month_name[1:13])
ax.barh(months, sales_quantity, height = 0.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Scatter plot**

# %%
#importing libraries
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
headers_cols = ['age','min_recommended', 'max_recommended',
'may_be_appropriate_min', 'may_be_appropriate_max', 'min_not_recommended',
'max_not_recommended']
sleepDf = pd.read_csv('https://raw.githubusercontent.com/PacktPublishing/hands-on-exploratory-data-analysis-with-python/master/Chapter%202/sleep_vs_age.csv', header=0, names=headers_cols)

sleepDf.head(10)
# Out:
#    age  min_recommended  max_recommended  may_be_appropriate_min  \
# 0    0               14               17                      11
# 1    1               14               17                      11
# 2    2               14               17                      11
# 3    3               14               17                      11
# 4    4               12               15                      10
# 5    5               12               15                      10
# 6    6               12               15                      10
# 7    7               12               15                      10
# 8    8               12               15                      10
# 9    9               12               15                      10
#
#    may_be_appropriate_max  min_not_recommended  max_not_recommended
# 0                      13                   11                   19
# 1                      13                   11                   19
# ...

# %%
#plotting the scatter plot
sns.set()
plt.rcParams['figure.figsize'] = (8, 6)
plt.scatter(x=sleepDf["age"], y=sleepDf["min_recommended"])
plt.scatter(x=sleepDf["age"], y=sleepDf['max_recommended'])
plt.xlabel('Age of person in Years')
plt.ylabel('Total hours of sleep required')
plt.show()

# %%
#plotting the scatter plot with markers as dotted lines
plt.rcParams['figure.figsize'] = (8, 6)
plt.scatter(x=sleepDf["age"]/12, y=sleepDf["min_recommended"])
plt.scatter(x=sleepDf["age"]/12, y=sleepDf["max_recommended"])
plt.show()

# %%
#Plot with dotted lines 
plt.rcParams['figure.figsize'] = (8, 6)
plt.plot(sleepDf['age']/12, sleepDf['min_recommended'], 'r--', label='min_recommended')
plt.plot(sleepDf['age']/12, sleepDf['max_recommended'], 'g--', label='max_recommended')
plt.xlabel('Age(years)')
plt.ylabel('No of hours needed for sleep')
plt.legend()
plt.show()

# %% [markdown]
# From the above scatter plot, we can see that the age increases, the hours needed to sleep decreases and becomes constant after 18 years.

# %%
#loading iris dataset from sea born


df = sns.load_dataset('iris')
df['species'] = df['species'].map({'setosa': 0, "versicolor": 1,
"virginica": 2})

plt.rcParams['figure.figsize'] = (10, 6)

plt.scatter(df['sepal_length'], df['sepal_width'], c=df['species'])
plt.xlabel('Sepal Length')
plt.ylabel('Sepal width')
plt.show()

# %% [markdown]
# **Bubble chart**

# %%
#Bubble chart
plt.rcParams['figure.figsize'] = (8, 6)
plt.scatter(df.petal_length, df.petal_width, s = 50 * df.petal_length * df.petal_width, c=df['species'], alpha = 0.3)
plt.xlabel('Petal length')
plt.ylabel('Petal width')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame
data = {
    'petal_length': [1.4, 1.5, 1.3, 1.5, 4.7, 4.5, 4.9, 5.0, 5.0, 5.0, 5.0, 5.0],
    'petal_width': [0.2, 0.2, 0.2, 0.2, 1.4, 1.5, 1.5, 1.6, 1.6, 1.6, 1.6, 1.6],
    'species': ['setosa', 'setosa', 'setosa', 'setosa', 
                'versicolor', 'versicolor', 'versicolor', 'virginica', 'versicolor', 'versicolor', 'versicolor', 'versicolor']
}

df = pd.DataFrame(data)

# Scatter plot with alpha
plt.figure(figsize=(8, 6))
plt.scatter(df.petal_length, df.petal_width,
            s=50,  # Size of the markers
            c=df.species.astype('category').cat.codes,  # Convert species to numeric for coloring
            alpha=0.1)  # Set transparency
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.title('Scatter Plot of Petal Length vs Petal Width')
plt.colorbar(label='Species (Encoded)')
plt.grid(True)
plt.show()

# %%
#importing libraries
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
###Scatter plot using seaborn
df = sns.load_dataset('iris')
df['species'] = df['species'].map({'setosa': 0, 'versicolor': 1, 'virginica': 2 })

sns.scatterplot(x=df['sepal_length'], y=df['sepal_width'], hue=df['species'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
###Plotting stacked plot or area plot
import random
sns.set()

#expenses
groceries = [100, 250, 220, 330, 220, 50, 350, 600, 300, 200, 230, 340]
rent = [random.randint(6000, 6500) for _ in range(12)]
food = [random.randint(3000, 3500) for _ in range(12)]
internet = [random.randint(300, 450) for _ in range(12)]

#months
months = [x for x in range(1, 13)]
plt.rcParams['figure.figsize'] = (8, 6)

#place holders for the plot and their labels
plt.plot([], [], color='sandybrown', label='groceries')
plt.plot([], [], color='tan', label='rent')
plt.plot([], [], color='bisque', label='food')
plt.plot([], [], color='darkcyan', label='internet')

#stackplot plotting
plt.stackplot(months, groceries, rent, food, internet, colors=['sandybrown', 'tan', 'bisque', 'darkcyan'])

plt.legend()

plt.title("Montly expenses")
plt.xlabel("Month of the year")
plt.ylabel("Cost")


plt.show()

# %%
##Pie chart

url = 'https://raw.githubusercontent.com/hmcuesta/PDA_Book/master/Chapter3/pokemonByType.csv'
df = pd.read_csv(url, index_col='type')
df
# Out:
#           amount
# type
# Bug           45
# Dark          16
# Dragon        12
# Electric       7
# Fighting       3
# Fire          14
# Ghost         10
# Grass         31
# Ground        17
# Ice           11
# Normal        29
# Poison        11
# Psychic        9
# Rock          24
# Steel         13
# Water         45

# %%
plt.pie(df['amount'], labels=df.index, shadow=False, startangle=90,autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %%
#one-liner to draw pie chart using the pandas
df.plot.pie(y='amount', figsize=(20, 10))
# Out:
# <Axes: ylabel='amount'>
